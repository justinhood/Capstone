# %%
import numpy as np
import seaborn as sns
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
oral=np.array([[0,3,19.63333,41.83333,64.9,70.1,71.3,71.46667,71.7,71.8],
[3,19.7,41.63333,65.8,71.66667,71.83333,71.93333,71.96667,72,72],
[19,42,66.33333,72,72,72,72,72,72,72],
[42,66.56667,72,72,72,72,72,72,72,72],
[68,72,72,72,72,72,72,72,72,72],
[72,72,72,72,72,72,72,72,72,72],
[72,72,72,72,72,72,72,72,72,72],
[72,72,72,72,72,72,72,72,72,72],
[72,72,72,72,72,72,72,72,72,72],
[72,72,72,72,72,72,72,72,72,72]])
oral.shape
# Out:
# (10, 10)

# %%
iv=np.array([[0,3.566667,25.53333,36.5,47.3,48,48,48,48,48],
[4,25.56667,37.03333,48,48,48,48,48,48,48],
[26,37.43333,48,48,48,48,48,48,48,48],
[38,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48],
[48,48,48,48,48,48,48,48,48,48]])
iv.shape
# Out:
# (10, 10)

# %%
total=oral+iv
total.shape
# Out:
# (10, 10)

# %%
total[1,0]
total[2,0]
# Out:
# 45.0

# %%
ax=sns.heatmap(total,cmap="gist_heat",linewidths=.5)

# %%
P=np.empty([10,10])
for i in range(0,10):
    for j in range(0,10):
        P[i,j]=55.99*total[i,j]-748.92*(i+1)-63.12*(j+1)

# %%
ay=sns.heatmap(P,cmap="gist_heat",linewidths=.5,center=0)
ay.set_xlabel("Technicians");
ay.set_ylabel("Pharmacists");

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
Tech=np.arange(1,11)
Pharm=np.arange(1,11)
Tech,Pharm=np.meshgrid(Tech,Pharm)
surf=ax.plot_surface(Tech,Pharm,P, cmap=cm.coolwarm,linewidth=0,antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
#ax.set_xlim(10,1)
ax.view_init(azim=175)
ax.set_xlabel("Technicians");
ax.set_ylabel("Pharmacists");

# %%
np.amax(P)
# Out:
# 5488.847

# %%
P
# Out:
# array([[ -812.04      ,  -507.49231467,  1590.6012934 ,  3384.4831467 ,
#          5217.558     ,  5484.779     ,  5488.847     ,  5435.0588533 ,
#          5385.003     ,  5327.482     ],
#        [-1169.03      ,   910.4008533 ,  2717.3462934 ,  4621.342     ,
#          4886.6968533 ,  4832.9081467 ,  4775.3871467 ,  4714.1338533 ,
#          4652.88      ,  4589.76      ],
#        [  209.67      ,  2074.4721467 ,  3965.4031467 ,  4219.56      ,
#          4156.44      ,  4093.32      ,  4030.2       ,  3967.08      ,
#          3903.96      ,  3840.84      ],
#        [ 1420.4       ,  3292.6678533 ,  3533.76      ,  3470.64      ,
#          3407.52      ,  3344.4       ,  3281.28      ,  3218.16      ,
#          3155.04      ,  3091.92      ],
#        [ 2687.12      ,  2847.96      ,  2784.84      ,  2721.72      ,
#          2658.6       ,  2595.48      ,  2532.36      ,  2469.24      ,
#          2406.12      ,  2343.        ],
#        [ 2162.16      ,  2099.04      ,  2035.92      ,  1972.8       ,
#          1909.68      ,  1846.56      ,  1783.44      ,  1720.32      ,
#          1657.2       ,  1594.08      ],
#        [ 1413.24      ,  1350.12      ,  1287.        ,  1223.88      ,
#          1160.76      ,  1097.64      ,  1034.52      ,   971.4       ,
#           908.28      ,   845.16      ],
#        [  664.32      ,   601.2       ,   538.08      ,   474.96      ,
#           411.84      ,   348.72      ,   285.6       ,   222.48      ,
#           159.36      ,    96.24      ],
#        [  -84.6       ,  -147.72      ,  -210.84      ,  -273.96      ,
#          -337.08      ,  -400.2       ,  -463.32      ,  -526.44      ,
#          -589.56      ,  -652.68      ],
#        [ -833.52      ,  -896.64      ,  -959.76      , -1022.88      ,
#         -1086.        , -1149.12      , -1212.24      , -1275.36      ,
#         -1338.48      , -1401.6       ]])

# %%
P[0,6]
# Out:
# 5488.847

# %%
P[0:3,5:8]
# Out:
# array([[5484.779    , 5488.847    , 5435.0588533],
#        [4832.9081467, 4775.3871467, 4714.1338533],
#        [4093.32     , 4030.2      , 3967.08     ]])
